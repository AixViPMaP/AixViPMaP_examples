# %% [markdown]
# # Numerical benchmark of phase-field simulation with elastic strains: Precipitation and chemo-mechanical coupling effect
#
# ![conc_map.PNG](attachment:conc_map.PNG)
#
# Elasticity coefficient $\mathbb{C}$ is expressed as a linear function of Li concentration $c$
#
# $\mathbb{C}^{ijkl}(c) = \mathbb{C}^{ijkl}_{ref}\left( 1 +  \kappa \Delta c \right)$ <div style="text-align: right"> (1) </div>
#
# The quasi-steady state solution for the concentration profile $c(r)$ around a single precipitate is:
#
# $c(r) = c_0 - g_0 \kappa \left( \frac{R}{r} \right)^6 + \left( g_0 \kappa - g_1 \right) \frac{R}{r} + O(\kappa^2)$ <div style="text-align: right"> (2) </div>
#
# Please enter the value of parameters $\kappa$ and $\mathbb{C}$ in the following form.

# %%
from BenchmarkAl3Li import BenchmarkAl3Li
app = BenchmarkAl3Li()
app.showUI()
# Out:
# Accordion(children=(VBox(children=(Text(value='SPP1713Benchmarks/Al3Li/OP', description='Job path'),)), VBox(children=(FloatText(value=0.01, description='$\\kappa$'), Label(value='Elasticity coefficient $\\mathbb{C}$ of the matrix phase'), FloatText(value=107110000000.0, description='$\\mathbb{C}_{11}$'), FloatText(value=62860000000.0, description='$\\mathbb{C}_{12}$'), FloatText(value=28470000000.0, description='$\\mathbb{C}_{44}$'), Button(description='Submit & Start simulation', style=ButtonStyle())))), _titles={'0': 'Working folder', '1': 'Benchmark parameters'})
# Simulation input file has been writen to ElasticityInput.opi
# Please open the <a href="https://condor.iehk.rwth-aachen.de/aixvipmap/index.php/apps/files/?dir=/Benchmark_Job2">Job folder</a> in a new window.

# %%
app.postprocessing()
# Out:
# Notebook initialized with x3d backend.
# Mayavi 4.5.1.dev0, vtk version 7.1.1, DISPLAY :99
#     <?xml version="1.0" encoding ="UTF-8"?>
#
# <X3D profile="Immersive" version="3.0" id="scene_0" >
#   <head>
#     <meta name="filename" content="Stream"/>
#     <meta name="generator" content="Visualization ToolKit X3D exporter v0.9.1"/>
#     <meta name="numberofelements" content="3"/>
#   </head>
#   <Scene>
#     <Background skyColor="0.5 0.5 0.5"/>
#     <Viewpoint fieldOfView="0.523599" position="75.3874 75.3874 75.3874" description="Default View" orientation="0.187053 0.451587 0.872399 -3.83511" centerOfRotation="15.5 15.5 15.5"/>
#     <NavigationInfo type='"EXAMINE" "FLY" "ANY"' speed="4" headlight="true"/>
#     <DirectionalLight ambientIntensity="1" intensity="0" color="1 1 1"/>
#     <Transform DEF="ROOT" translation="0 0 0">
#       <DirectionalLight direction="0 -6.12323e-17 -1" color="1 1 1" intensity="1" on="true"/>
# ...
